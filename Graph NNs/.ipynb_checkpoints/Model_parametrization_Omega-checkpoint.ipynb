# %%
from rdkit import Chem
import chemlib
from chemlib import Element

import numpy as np
import pandas as pd
import os
from functools import partial

from ray import train
from ray import tune
from ray.tune.schedulers import ASHAScheduler

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import torch
import torch.nn as nn
from torch_geometric.data import Data, Dataset
from torch_geometric.nn import global_mean_pool, GraphConv, NNConv, EdgeConv
from torch_geometric.loader import DataLoader
device = 'cuda:0'
from ray.tune.search.hyperopt import HyperOptSearch
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
# Out:
# 2025-02-20 10:09:08,136	INFO util.py:154 -- Outdated packages:
#   ipywidgets==7.8.1 found, needs ipywidgets>=8
# Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# 2025-02-20 10:09:08,505	INFO util.py:154 -- Outdated packages:
#   ipywidgets==7.8.1 found, needs ipywidgets>=8
# Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\typing.py:86: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: [WinError 127] Не найдена указанная процедура
#   warnings.warn(f"An issue occurred while importing 'torch-scatter'. "
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: [WinError 127] Не найдена указанная процедура
#   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "

# %%
#abs_path is made for function "load_data" so that is doesn't lose table with descriptors
path = os.path.abspath('') + '\\grouped_table.csv'

# %% [markdown]
# The function "load_data" according to its name, loads data from table with structures and target values. Actually, it unites loading from .csv file, creating .mol column, dropping all above 95% percentile and creating train, validation and test datasets

# %%
def load_data(abs_path = path, variable = 'Tc'):
    df = pd.read_csv(abs_path, index_col = 0)
    df = df[~df[variable].isnull()]
    df['mol'] = df['SMILES'].apply(lambda x: Chem.MolFromSmiles(x))
    quant = df[variable].quantile(q= 0.95)
    mask = df[variable] < quant
    df = df[mask]

    train_df, test_df = train_test_split(df, test_size = 0.2, random_state = 0)
    
    valid_df, test_df = train_test_split(test_df, test_size = 0.5, random_state = 0)
    return train_df, test_df, valid_df

# %% [markdown]
# In the cell below we check that function works and create test dataset, that will be useful in the end

# %%
train_df, test_df, valid_df = load_data()

# %% [markdown]
# Functions below, class CriticalDataset and GraphNet are taken from *model_architecture_search.ipynb* and are well-described there. Please, refer to this file.

# %%
def make_edge_features(mol):
    edge_features = np.zeros([mol.GetNumBonds(), 4])
    for i, bond in enumerate(mol.GetBonds()):
        if bond.GetBondTypeAsDouble() == 1.0:
            edge_features[i,0] = 1
        elif bond.GetBondTypeAsDouble() == 2.0:
            edge_features[i,1] = 1
        elif bond.GetBondTypeAsDouble() == 3.0:
            edge_features[i, 2] = 1
        else:
            edge_features[i, 3] = 1
    return torch.tensor(edge_features, dtype = torch.float32)

# %%
def make_x(mol):
    atom_properties = []
    
    for atom in mol.GetAtoms():
        _el = Element(atom.GetSymbol())
        atom_properties.append([atom.GetAtomicNum(), atom.GetMass(), int(atom.GetIsAromatic()), atom.GetExplicitValence(), 
                                atom.GetImplicitValence(), atom.GetTotalValence(), 
                                atom.GetNumExplicitHs(), atom.GetNumImplicitHs(), atom.GetTotalNumHs(),
                                atom.GetDegree(), atom.GetTotalDegree(), atom.GetFormalCharge(),
                               int(atom.IsInRing()), _el.Electronegativity, _el.FirstIonization, _el.AtomicRadius, _el.SpecificHeat
                               ])
    x = torch.tensor(atom_properties, dtype = torch.float32)
    return x

# %%
def make_edge_indices(mol):
    start_atoms = []
    end_atoms = []
    for bond in mol.GetBonds():
        start_atoms.append(bond.GetBeginAtomIdx())
        end_atoms.append(bond.GetEndAtomIdx())
    edge_indice = torch.tensor([start_atoms, end_atoms], dtype = torch.int64)
    return edge_indice

# %%
class CriticalDataset(Dataset):
    def __init__(self, frame, labels = None, transform = None, property = 'Tc'):
        super().__init__()
        self.property = property    
        self.df = frame[~frame[self.property].isnull()]
        self.labels = None
        self.transform = None
    def get(self, idx):
        mol = self.df['mol'].iloc[idx]
        #print(Chem.MolToSmiles(mol))
        try:
            x = make_x(mol)
        except:
            print('Invalid mol - cannot make x')
        try:
            edge_indices = make_edge_indices(mol)
        except:
            print('Invalid mol - cannot make edge indice')
        try:
            edge_features = make_edge_features(mol)
        except:
            print('Invalid mol - cannot make edge features')
        y = torch.tensor(self.df[self.property].iloc[idx], dtype = torch.float32)
        data = Data(x=x, edge_index=edge_indices, y = y, edge_features = edge_features)
        return data
    def len(self):
        return(len(self.df))

# %% [markdown]
# This is the optimal acrhitecture, that we found earlier, in *model_architecture_search.ipynb*. However, we want to vary number of neurons on convolutional layers, which is crucial for good prediction. Therefore, when creating the class, we leave a space to do it, using parameters *n1*, *n2*, *n3*, *n4*. Other architecture features are the same

# %%
class GraphNet(nn.Module):
    def __init__(self, num_node_features = 17,
                n1 = 200,
                n2 = 500,
                n3 = 500,
                n4 = 500):
        super().__init__()
        conv_1_nn = nn.Sequential(nn.Linear(4, 200), nn.ReLU(), nn.Linear(200, 17*n1))
        self.conv_1 = NNConv(17, n1, nn = conv_1_nn)
        self.a1_con = nn.ReLU()
        
        conv_2_nn = nn.Sequential(nn.Linear(2*n1, n2), nn.ReLU(), nn.Linear(n2, n2))
        self.conv_2 = EdgeConv(nn = conv_2_nn)
        self.a2_con = nn.ReLU()
        
        conv_3_nn = nn.Sequential(nn.Linear(2*n2, n3), nn.ReLU(), nn.Linear(n3, n3))
        self.conv_3 = EdgeConv(nn = conv_3_nn)
        self.a3_con = nn.ReLU()
        
        self.conv_4 = GraphConv(in_channels = n3, out_channels = n4)
        self.a4_con = nn.ReLU()
        self.dropout_1 = nn.Dropout(p = 0.3)
        self.a1 = nn.CELU()
        self.linear_1 = nn.Linear(in_features = n4, out_features = 1000)
        self.a2 = nn.CELU()
        self.linear_2 = nn.Linear(in_features = 1000, out_features = 1000)
        self.a3 = nn.CELU()
        self.linear_3 = nn.Linear(in_features = 1000, out_features = 1)
    def forward(self, data):
        x, edge_index, edge_attrs =  (data.x, data.edge_index, data.edge_features)
        x = self.a1_con(self.conv_1(x = x, edge_index = edge_index, edge_attr = edge_attrs))
        x = self.a2_con(self.conv_2(x = x, edge_index = edge_index))
        x = self.a3_con(self.conv_3(x = x, edge_index = edge_index))
        x = self.a4_con(self.conv_4(x = x, edge_index = edge_index))
        if hasattr(data, 'batch'):
            x = global_mean_pool(x, batch = data.batch)
        else:
            x = torch.mean(x, dim = 0, keepdim = True)
        #x = self.a1(x)
        x = self.dropout_1(x)
        x = self.linear_1(x)
        x = self.a2(x)
        x = self.linear_2(x)
        x = self.a3(x)
        x = self.linear_3(x)
        return x

# %% [markdown]
# Ths config file is used here just to define the function)

# %%
config = {
    "n1": tune.qrandint(100, 1000, 100),
    "n2": tune.qrandint(100, 1000, 100),
    "n3": tune.qrandint(100, 1000, 100),
    "n4": tune.qrandint(100, 1000, 100),
    "n_epochs": tune.qrandint(1, 50, 5),
    "lr": tune.loguniform(1e-4, 1e-2)}

# %% [markdown]
# This function is crucial for the search of optimal hyperparameters. It has following arguments:
# 1. Config - dictionary with learning rate ('lr') and number of neurons in first and second linear layers ('l1' and 'l2')
# 2. abs_path - is the path of *table_with_descriptors.csv* - second cell of this Notebook
# 3.  Is_tune - flags if this function is used in Ray Tune instance to find optimal hyperparameters (True) or in model training with known hyperparameters (False)

# %%
def train_model(config = config, 
                abs_path  = path,
                variable = 'Tc',
                is_tune = True):
    #first we create train, test and validation dataset
    train_df, test_df, valid_df = load_data(abs_path = abs_path, variable = variable)
    #if is_tune is True, i.e. our goal is to determine optimal model hyperparameters, three datasets are created
    if is_tune:
        train_ds, test_ds,  valid_ds = (CriticalDataset(train_df, property = variable), 
                                        CriticalDataset(test_df, property = variable), 
                                        CriticalDataset(valid_df,property = variable))
        train_dl, test_dl, valid_dl = (DataLoader(train_ds, batch_size=2), DataLoader(test_ds, batch_size =2),  DataLoader(valid_ds, batch_size=2))
    #if is_tune is false, i.e. our goal is to get trained model, training and validation datasets are concatenated
    else:
        train_df = pd.concat([train_df, test_df])
        train_ds, valid_ds = (CriticalDataset(train_df, property = variable), 
                              CriticalDataset(valid_df, property = variable))
        train_dl, valid_dl = (DataLoader(train_ds, batch_size = 2), DataLoader(valid_ds, batch_size = 2))
    #here we instantiate the model with n1, n2, n3, n4 from config - search space    
    model = GraphNet(n1 = config['n1'], n2 = config['n2'], n3 = config['n3'], n4 = config['n4'])
    model.to(device)
    optimizer = torch.optim.Adam(params = model.parameters(), lr = config['lr'])
    loss_fn = nn.MSELoss()
    #number of training epochs is also parameter to vary
    for epoch in range(config['n_epochs']):
        # perform the training-validation loop and assess all metrics
        epoch_train_loss, epoch_valid_loss, epoch_train_rmse, epoch_valid_rmse, epoch_r2_valid, total_graphs = 0, 0, 0, 0, 0, 0
        model.train()
        for batch in train_dl:
            batch.to(device)
            output = model(batch)
            loss = loss_fn(output.flatten(), batch.y)
            #obligatory step! if not zeroed, graph training will just return average value
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            epoch_train_loss += loss.item()
            epoch_train_rmse += (output.flatten() -batch.y).pow(2).sum().item()
            total_graphs += batch.num_graphs
            
        epoch_train_loss = epoch_train_loss / total_graphs
        epoch_train_rmse = np.sqrt(epoch_train_rmse/total_graphs)
        
        model.eval()
        total_graphs = 0
        #predictions and ys are used after loop to calculate r2 value
        predictions = []
        ys = []
        for batch in valid_dl:
            batch.to(device)
            output = model(batch)
            loss = loss_fn(output.flatten(), batch.y)
            epoch_valid_loss += loss.item()
            epoch_valid_rmse += (output.flatten() -batch.y).pow(2).sum().item()
            total_graphs += batch.num_graphs
            predictions.append(output)
            ys.append(batch.y)
            
        predictions = torch.cat(predictions, dim = 0).detach().cpu().numpy()
        ys = torch.cat(ys, dim = 0).detach().cpu().numpy()
        epoch_valid_loss = epoch_valid_loss / total_graphs
        epoch_valid_rmse = np.sqrt(epoch_valid_rmse / total_graphs)
        epoch_r2_valid = r2_score(ys, predictions.squeeze())
        #if our goal is not to use function in tune run, we print validation metrics on every step
        if not is_tune:
            print('vali loss is:', epoch_valid_loss, ' valid rmse is: ', epoch_valid_rmse, ' R2 valid is ',  epoch_r2_valid)
        #if our goal is  to use function in tune run, we report all metrics on every step
        if is_tune:
            train.report({'train_loss':epoch_train_loss,
                          'train_rmse':epoch_train_rmse,
                          'valid_loss':epoch_valid_loss,
                          'valid_rmse':epoch_valid_rmse,
                          'r2_valid':epoch_r2_valid})
    #if our goal is not to use function in tune run, in the end of the training we return trained model and draw predicted vs real values
    if not is_tune:
        sns.scatterplot(x = predictions.squeeze(), y = ys)
        return model

# %% [markdown]
# Here we check that function works well for just model training

# %%
config = {
    "n1": 200,
    "n2": 500,
    "n3": 500,
    "n4": 500,
    "n_epochs": 3,
    "lr": 0.0001}
model = train_model(config = config, is_tune = False, variable = 'omega')
# Out:
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 0.009149772028930732  valid rmse is:  0.13527580736355435  R2 valid is  0.4359167814254761
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 0.006551091881061157  valid rmse is:  0.11446477083418424  R2 valid is  0.5961253643035889
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 0.008837730904896882  valid rmse is:  0.13294909480622183  R2 valid is  0.4551541209220886

# %% [markdown]
# Instantiate config with search space

# %%
config = {
    "n1": tune.qrandint(100, 1000, 100),
    "n2": tune.qrandint(100, 1000, 100),
    "n3": tune.qrandint(100, 1000, 100),
    "n4": tune.qrandint(100, 1000, 100),
    "n_epochs": tune.qrandint(1, 50, 5),
    "lr": tune.loguniform(1e-4, 1e-2)}

# %% [markdown]
# Instantiate algorithm, maximum number of epochs, scheduler and run the Ray Tune

# %%
hpt_search = HyperOptSearch(metric = 'valid_loss', mode = 'min')

# %%
max_num_epochs = 50
scheduler = ASHAScheduler(metric = 'valid_loss', mode = 'min', max_t = max_num_epochs, grace_period= 5, reduction_factor=2)

# %%
result = tune.run(partial(train_model, variable = 'omega'), search_alg = hpt_search, config = config, num_samples = 25, scheduler = scheduler, resources_per_trial={'gpu':1})
# Out:
# 2025-02-20 10:10:34,937	INFO worker.py:1810 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# 2025-02-20 10:10:38,221	INFO tune.py:253 -- Initializing Ray automatically. For cluster usage or custom Ray initialization, call `ray.init(...)` before `tune.run(...)`.
# 2025-02-20 10:10:38,224	INFO tune.py:616 -- [output] This uses the legacy output and progress reporter, as Jupyter notebooks are not supported by the new engine, yet. For more information, please see https://github.com/ray-project/ray/issues/36949
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2025-02-20 14:48:15</td></tr>
# <tr><td>Running for: </td><td>04:37:37.39        </td></tr>
# <tr><td>Memory:      </td><td>13.0/31.9 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using AsyncHyperBand: num_stopped=17<br>Bracket: Iter 40.000: -0.0030851502052992993 | Iter 20.000: -0.003121864115150967 | Iter 10.000: -0.003820172227861116 | Iter 5.000: -0.008576730146678755<br>Logical resource usage: 0/16 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name          </th><th>status    </th><th>loc            </th><th style="text-align: right;">         lr</th><th style="text-align: right;">  n1</th><th style="text-align: right;">  n2</th><th style="text-align: right;">  n3</th><th style="text-align: right;">  n4</th><th style="text-align: right;">  n_epochs</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  train_loss</th><th style="text-align: right;">   train_rmse</th><th style="text-align: right;">  valid_loss</th></tr>
# </thead>
# <tbody>
# <tr><td>train_model_0d2460cd</td><td>TERMINATED</td><td>127.0.0.1:15888</td><td style="text-align: right;">0.000539409</td><td style="text-align: right;"> 200</td><td style="text-align: right;">1000</td><td style="text-align: right;"> 800</td><td style="text-align: right;"> 400</td><td style="text-align: right;">        10</td><td style="text-align: right;">    10</td><td style="text-align: right;">         437.791</td><td style="text-align: right;"> 0.011823   </td><td style="text-align: right;">    0.153772 </td><td style="text-align: right;">  0.0104504 </td></tr>
# <tr><td>train_model_a9b14748</td><td>TERMINATED</td><td>127.0.0.1:13084</td><td style="text-align: right;">0.000138423</td><td style="text-align: right;"> 300</td><td style="text-align: right;"> 600</td><td style="text-align: right;"> 900</td><td style="text-align: right;"> 600</td><td style="text-align: right;">        50</td><td style="text-align: right;">    50</td><td style="text-align: right;">        2316.19 </td><td style="text-align: right;"> 0.00172636 </td><td style="text-align: right;">    0.0587598</td><td style="text-align: right;">  0.00304758</td></tr>
# <tr><td>train_model_adf77d90</td><td>TERMINATED</td><td>127.0.0.1:5860 </td><td style="text-align: right;">0.00728001 </td><td style="text-align: right;"> 700</td><td style="text-align: right;"> 500</td><td style="text-align: right;"> 800</td><td style="text-align: right;"> 900</td><td style="text-align: right;">        35</td><td style="text-align: right;">     5</td><td style="text-align: right;">         236.922</td><td style="text-align: right;"> 7.27207e+08</td><td style="text-align: right;">38136.8      </td><td style="text-align: right;">  0.158091  </td></tr>
# <tr><td>train_model_1db87ec3</td><td>TERMINATED</td><td>127.0.0.1:19776</td><td style="text-align: right;">0.000401807</td><td style="text-align: right;"> 500</td><td style="text-align: right;"> 800</td><td style="text-align: right;"> 600</td><td style="text-align: right;"> 600</td><td style="text-align: right;">        20</td><td style="text-align: right;">    10</td><td style="text-align: right;">         473.26 </td><td style="text-align: right;"> 0.0110306  </td><td style="text-align: right;">    0.14853  </td><td style="text-align: right;">  0.0102989 </td></tr>
# <tr><td>train_model_72f3df78</td><td>TERMINATED</td><td>127.0.0.1:13952</td><td style="text-align: right;">0.000305161</td><td style="text-align: right;"> 800</td><td style="text-align: right;"> 200</td><td style="text-align: right;"> 500</td><td style="text-align: right;"> 800</td><td style="text-align: right;">        10</td><td style="text-align: right;">    10</td><td style="text-align: right;">         466.117</td><td style="text-align: right;"> 0.00565259 </td><td style="text-align: right;">    0.106326 </td><td style="text-align: right;">  0.00391444</td></tr>
# <tr><td>train_model_d39776e4</td><td>TERMINATED</td><td>127.0.0.1:11016</td><td style="text-align: right;">0.0071348  </td><td style="text-align: right;"> 800</td><td style="text-align: right;"> 700</td><td s
# (pid=15888) Windows fatal exception: code 0xc0000139
# (pid=15888)
# (pid=15888) Stack (most recent call first):
# (pid=15888)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\ctypes\__init__.py", line 376 in __init__
# (pid=15888)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\_ops.py", line 1350 in load_library
# (pid=15888)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_scatter\__init__.py", line 16 in <module>
# (pid=15888)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=15888)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=15888)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=15888)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=15888)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=15888)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\typing.py", line 82 in <module>
# (pid=15888)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=15888)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=15888)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=15888)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=15888)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=15888)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\__init__.py", line 4 in <module>
# (pid=15888)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=15888)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=15888)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=15888)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=15888)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=15888)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=15888)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (pid=15888)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=15888)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=15888)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (pid=15888)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=15888)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\function_manager.py", line 647 in _load_actor_class_from_gcs
# (pid=15888)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\function_manager.py", line 544 in load_actor_class
# (pid=15888)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\worker.py", line 920 in main_loop
# (pid=15888)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\workers\default_worker.py", line 289 in <module>
# (pid=15888) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\typing.py:86: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: [WinError 127] Не найдена указанная процедура
# (pid=15888)   warnings.warn(f"An issue occurred while importing 'torch-scatter'. "
# (pid=15888) Windows fatal exception: code 0xc0000139
# (pid=15888)
# (pid=15888) Stack (most recent call first):
# (pid=15888)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\ctypes\__init__.py", line 376 in __init__
# (pid=15888)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\_ops.py", line 1350 in load_library
# (pid=15888)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_scatter\__init__.py", line 16 in <module>
# (pid=15888)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=15888)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=15888)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=15888)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=15888)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=15888)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_sparse\storage.py", line 5 in <module>
# (pid=15888)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=15888)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=15888)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=15888)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=15888)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=15888)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_sparse\__init__.py", line 39 in <module>
# (pid=15888)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=15888)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=15888)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=15888)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=15888)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=15888)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\typing.py", line 119 in <module>
# (pid=15888)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=15888)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=15888)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=15888)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=15888)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=15888)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\__init__.py", line 4 in <module>
# (pid=15888)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=15888)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=15888)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=15888)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=15888)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=15888)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=15888)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (pid=15888)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=15888)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=15888)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (pid=15888)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=15888)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\function_manager.py", line 647 in _load_actor_class_from_gcs
# (pid=15888)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\function_manager.py", line 544 in load_actor_class
# (pid=15888)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\worker.py", line 920 in main_loop
# (pid=15888)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private
td></tr>
# </tbody>
# </table>
# </div>
# <style>
# .trialProgress {
#   display: flex;
#   flex-direction: column;
#   color: var(--jp-ui-font-color1);
# }
# .trialProgress h3 {
#   font-weight: bold;
# }
# .trialProgress td {
#   white-space: nowrap;
# }
# </style>
# (func pid=15888) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=15888)   warnings.warn(message)
# (func pid=15888) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=15888)   warnings.warn(message)
# (func pid=15888) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=15888)   warnings.warn(message)
# (func pid=15888) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=15888)   warnings.warn(message)
# (func pid=15888) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=15888)   warnings.warn(message)
# (func pid=15888) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=15888)   warnings.warn(message)
# (func pid=15888) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=15888)   warnings.warn(message)
# (func pid=15888) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=15888)   warnings.warn(message)
# (func pid=15888) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=15888)   warnings.warn(message)
# (func pid=15888) D:\bld\apache-arrow_1692865689659\work\cpp\src\arrow\filesystem\s3fs.cc:2829:  arrow::fs::FinalizeS3 was not called even though S3 was initialized.  This could lead to a segmentation fault at exit
# (pid=22204) Windows fatal exception: code 0xc0000139
# (pid=22204)
# (pid=22204) Stack (most recent call first):
# (pid=22204)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\ctypes\__init__.py", line 376 in __init__
# (pid=22204)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\_ops.py", line 1350 in load_library
# (pid=22204)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_scatter\__init__.py", line 16 in <module>
# (pid=22204)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=22204)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=22204)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=22204)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=22204)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=22204)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\typing.py", line 82 in <module>
# (pid=22204)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=22204)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=22204)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=22204)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=22204)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=22204)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\__init__.py", line 4 in <module>
# (pid=22204)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=22204)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=22204)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=22204)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=22204)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=22204)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=22204)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (pid=22204)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=22204)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=22204)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (pid=22204)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=22204)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\function_manager.py", line 647 in _load_actor_class_from_gcs
# (pid=22204)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\function_manager.py", line 544 in load_actor_class
# (pid=22204)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\worker.py", line 920 in main_loop
# (pid=22204)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\workers\default_worker.py", line 289 in <module>
# (pid=22204) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\typing.py:86: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: [WinError 127] Не найдена указанная процедура
# (pid=22204)   warnings.warn(f"An issue occurred while importing 'torch-scatter'. "
# (pid=22204) Windows fatal exception: code 0xc0000139
# (pid=22204)
# (pid=22204) Stack (most recent call first):
# (pid=22204)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\ctypes\__init__.py", line 376 in __init__
# (pid=22204)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\_ops.py", line 1350 in load_library
# (pid=22204)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_scatter\__init__.py", line 16 in <module>
# (pid=22204)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=22204)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=22204)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=22204)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=22204)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=22204)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_sparse\storage.py", line 5 in <module>
# (pid=22204)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=22204)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=22204)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=22204)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=22204)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=22204)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_sparse\__init__.py", line 39 in <module>
# (pid=22204)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=22204)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=22204)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=22204)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=22204)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=22204)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\typing.py", line 119 in <module>
# (pid=22204)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=22204)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=22204)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=22204)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=22204)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=22204)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\__init__.py", line 4 in <module>
# (pid=22204)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=22204)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=22204)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=22204)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=22204)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=22204)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=22204)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (pid=22204)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=22204)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=22204)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (pid=22204)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=22204)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\function_manager.py", line 647 in _load_actor_class_from_gcs
# (pid=22204)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\function_manager.py", line 544 in load_actor_class
# (pid=22204)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\worker.py", line 920 in main_loop
# (pid=22204)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\workers\default_worker.py", line 289 in <module>
# (pid=22204) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: [WinError 127] Не найдена указанная процедура
# (pid=22204)   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "
# (func pid=22204) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=22204)   warnings.warn(message)
# (func pid=22204) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=22204)   warnings.warn(message)
# (func pid=22204) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=22204)   warnings.warn(message)
# (func pid=22204) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=22204)   warnings.warn(message)
# (func pid=22204) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=22204)   warnings.warn(message)
# (func pid=22204) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=22204)   warnings.warn(message)
# (func pid=22204) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=22204)   warnings.warn(message)
# (func pid=22204) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=22204)   warnings.warn(message)
# (func pid=22204) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=22204)   warnings.warn(message)
# (func pid=22204) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=22204)   warnings.warn(message)
# (func pid=22204) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=22204)   warnings.warn(message)
# (func pid=22204) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=22204)   warnings.warn(message)
# (func pid=22204) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=22204)   warnings.warn(message)
# (func pid=22204) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=22204)   warnings.warn(message)
# (func pid=22204) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=22204)   warnings.warn(message)
# (func pid=22204) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=22204)   warnings.warn(message)
# (func pid=22204) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=22204)   warnings.warn(message)
# (func pid=22204) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=22204)   warnings.warn(message)
# (func pid=22204) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=22204)   warnings.warn(message)
# (func pid=22204) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=22204)   warnings.warn(message)
# (func pid=22204) D:\bld\apache-arrow_1692865689659\work\cpp\src\arrow\filesystem\s3fs.cc:2829:  arrow::fs::FinalizeS3 was not called even though S3 was initialized.  This could lead to a segmentation fault at exit
# (pid=6048) Windows fatal exception: code 0xc0000139
# (pid=6048)
# (pid=6048) Stack (most recent call first):
# (pid=6048)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\ctypes\__init__.py", line 376 in __init__
# (pid=6048)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\_ops.py", line 1350 in load_library
# (pid=6048)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_scatter\__init__.py", line 16 in <module>
# (pid=6048)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=6048)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=6048)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=6048)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=6048)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=6048)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\typing.py", line 82 in <module>
# (pid=6048)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=6048)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=6048)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=6048)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=6048)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=6048)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\__init__.py", line 4 in <module>
# (pid=6048)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=6048)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=6048)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=6048)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=6048)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=6048)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=6048)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (pid=6048)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=6048)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=6048)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (pid=6048)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=6048)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\function_manager.py", line 647 in _load_actor_class_from_gcs
# (pid=6048)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\function_manager.py", line 544 in load_actor_class
# (pid=6048)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\worker.py", line 920 in main_loop
# (pid=6048)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\workers\default_worker.py", line 289 in <module>
# (pid=6048) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\typing.py:86: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: [WinError 127] Не найдена указанная процедура
# (pid=6048)   warnings.warn(f"An issue occurred while importing 'torch-scatter'. "
# (pid=6048) Windows fatal exception: code 0xc0000139
# (pid=6048)
# (pid=6048) Stack (most recent call first):
# (pid=6048)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\ctypes\__init__.py", line 376 in __init__
# (pid=6048)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\_ops.py", line 1350 in load_library
# (pid=6048)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_scatter\__init__.py", line 16 in <module>
# (pid=6048)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=6048)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=6048)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=6048)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=6048)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=6048)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_sparse\storage.py", line 5 in <module>
# (pid=6048)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=6048)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=6048)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=6048)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=6048)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=6048)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_sparse\__init__.py", line 39 in <module>
# (pid=6048)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=6048)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=6048)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=6048)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=6048)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=6048)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\typing.py", line 119 in <module>
# (pid=6048)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=6048)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=6048)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=6048)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=6048)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=6048)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\__init__.py", line 4 in <module>
# (pid=6048)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=6048)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=6048)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=6048)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=6048)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=6048)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=6048)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (pid=6048)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=6048)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=6048)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (pid=6048)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# ...
# (pid=23592)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=23592)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=23592)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\typing.py", line 82 in <module>
# (pid=23592)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=23592)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=23592)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=23592)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=23592)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=23592)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\__init__.py", line 4 in <module>
# (pid=23592)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=23592)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=23592)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=23592)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=23592)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=23592)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=23592)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (pid=23592)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=23592)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=23592)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (pid=23592)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=23592)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\function_manager.py", line 647 in _load_actor_class_from_gcs
# (pid=23592)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\function_manager.py", line 544 in load_actor_class
# (pid=23592)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\worker.py", line 920 in main_loop
# (pid=23592)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\workers\default_worker.py", line 289 in <module>
# (pid=23592) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\typing.py:86: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: [WinError 127] Не найдена указанная процедура
# (pid=23592)   warnings.warn(f"An issue occurred while importing 'torch-scatter'. "
# (pid=23592) Windows fatal exception: code 0xc0000139
# (pid=23592)
# (pid=23592) Stack (most recent call first):
# (pid=23592)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\ctypes\__init__.py", line 376 in __init__
# (pid=23592)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\_ops.py", line 1350 in load_library
# (pid=23592)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_scatter\__init__.py", line 16 in <module>
# (pid=23592)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=23592)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=23592)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=23592)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=23592)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=23592)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_sparse\storage.py", line 5 in <module>
# (pid=23592)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=23592)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=23592)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=23592)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=23592)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=23592)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_sparse\__init__.py", line 39 in <module>
# (pid=23592)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=23592)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=23592)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=23592)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=23592)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=23592)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\typing.py", line 119 in <module>
# (pid=23592)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=23592)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=23592)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=23592)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=23592)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=23592)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\__init__.py", line 4 in <module>
# (pid=23592)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=23592)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=23592)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=23592)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=23592)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=23592)   File "<frozen importlib._bootstrap>"
# (pid=23592) , line 241 in _call_with_frames_removed
# (pid=23592)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (pid=23592)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=23592)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=23592)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (pid=23592)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=23592)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\function_manager.py", line 647 in _load_actor_class_from_gcs
# (pid=23592)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\function_manager.py", line 544
# (pid=23592)  in load_actor_class
# (pid=23592)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\worker.py", line 920 in main_loop
# (pid=23592)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\workers\default_worker.py"
# (pid=23592) , line 289 in <module>
# (pid=23592) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: [WinError 127] Не найдена указанная процедура
# (pid=23592)   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "
# (func pid=23592) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=23592)   warnings.warn(message)
# (func pid=23592) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=23592)   warnings.warn(message)
# (func pid=23592) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=23592)   warnings.warn(message)
# (func pid=23592) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=23592)   warnings.warn(message)
# (func pid=23592) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=23592)   warnings.warn(message)
# (func pid=23592) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=23592)   warnings.warn(message)
# (func pid=23592) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=23592)   warnings.warn(message)
# (func pid=23592) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=23592)   warnings.warn(message)
# (func pid=23592) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=23592)   warnings.warn(message)
# (func pid=23592) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=23592)   warnings.warn(message)
# (func pid=23592) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=23592)   warnings.warn(message)
# (func pid=23592) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=23592)   warnings.warn(message)
# (func pid=23592) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=23592)   warnings.warn(message)
# (func pid=23592) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=23592)   warnings.warn(message)
# (func pid=23592) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=23592)   warnings.warn(message)
# (func pid=23592) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=23592)   warnings.warn(message)
# (func pid=23592) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=23592)   warnings.warn(message)
# (func pid=23592) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=23592)   warnings.warn(message)
# (func pid=23592) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=23592)   warnings.warn(message)
# (func pid=23592) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=23592)   warnings.warn(message)
# (func pid=23592) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=23592)   warnings.warn(message)
# (func pid=23592) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=23592)   warnings.warn(message)
# (func pid=23592) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=23592)   warnings.warn(message)
# (func pid=23592) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=23592)   warnings.warn(message)
# (func pid=23592) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=23592)   warnings.warn(message)
# (func pid=23592) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=23592)   warnings.warn(message)
# (func pid=23592) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=23592)   warnings.warn(message)
# (func pid=23592) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=23592)   warnings.warn(message)
# (func pid=23592) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=23592)   warnings.warn(message)
# (func pid=23592) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=23592)   warnings.warn(message)
# 2025-02-20 14:48:15,877	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to 'C:/Users/Timur/ray_results/train_model_2025-02-20_10-10-38' in 0.0420s.
# 2025-02-20 14:48:15,890	INFO tune.py:1041 -- Total run time: 16657.67 seconds (16657.35 seconds for the tuning loop).

# %% [markdown]
# Let's print DataFrame with all metrics for the Ray Tune run

# %%
result.dataframe()
# Out:
#       train_loss    train_rmse  valid_loss  valid_rmse  r2_valid   timestamp  \
# 0   1.182299e-02      0.153772    0.010450    0.144571  0.355731  1740035881
# 1   4.046861e-03      0.089965    0.003339    0.081721  0.794140  1740036772
# 2   1.478636e-02      0.171967    0.012868    0.160427  0.206660  1740037029
# 3   3.142653e-03      0.079280    0.002929    0.076540  0.819414  1740038159
# 4   4.407064e-03      0.093884    0.003457    0.083144  0.786907  1740038622
# 5   1.635139e-02      0.180839    0.013567    0.164725  0.163580  1740038890
# 6   1.532024e-02      0.175044    0.013234    0.162692  0.184103  1740039125
# 7   1.726359e-03      0.058760    0.003048    0.078072  0.812116  1740041447
# 8   7.272073e+08  38136.787920    0.158091    0.562300 -8.746281  1740041690
# 9   1.103064e-02      0.148530    0.010299    0.143519  0.365072  1740042168
# 10  5.652589e-03      0.106326    0.003914    0.088481  0.758675  1740042641
# 11  7.287708e-02      0.381778    0.115553    0.480734 -6.123820  1740042889
# 12  3.932739e-03      0.088688    0.003992    0.089352  0.753902  1740043980
# 13  1.502374e-02      0.173342    0.013768    0.165937  0.151231  1740044219
# 14  1.477538e-02      0.171903    0.012794    0.159963  0.211250  1740044464
# 15  1.327583e-02      0.162947    0.013012    0.161320  0.197809  1740044708
# 16  9.521847e-03      0.137999    0.007798    0.124884  0.519251  1740044982
# 17  2.041256e-02      0.202052    0.016375    0.180970 -0.009527  1740045217
# 18  4.986798e-03      0.099868    0.004042    0.089906  0.750838  1740045689
# 19  1.468042e-02      0.171350    0.013175    0.162325  0.187775  1740045929
# 20  7.466344e-03      0.122199    0.005577    0.105614  0.656166  1740046483
# 21  1.928728e-03      0.062108    0.002932    0.076581  0.819223  1740048912
# 22  3.031020e-03      0.077859    0.003434    0.082874  0.788292  1740049875
# 23  5.364944e-03      0.103585    0.006030    0.109821  0.628229  1740050423
# 24  2.937895e-03      0.076654    0.003716    0.086215  0.770878  1740052095
#
#    checkpoint_dir_name   done  training_iteration  trial_id  ...    node_ip  \
# 0                 None  False                  10  0d2460cd  ...  127.0.0.1
# 1                 None  False                  20  c0a74e4c  ...  127.0.0.1
# 2                 None   True                   5  e53f86e8  ...  127.0.0.1
# 3                 None  False                  25  70073b7b  ...  127.0.0.1
# 4                 None  False                  10  9ba7349b  ...  127.0.0.1
# 5                 None   True                   5  08cbe69c  ...  127.0.0.1
# 6                 None   True                   5  5b460929  ...  127.0.0.1
# 7                 None   True                  50  a9b14748  ...  127.0.0.1
# 8                 None   True                   5  adf77d90  ...  127.0.0.1
# 9                 None   True                  10  1db87ec3  ...  127.0.0.1
# 10                None  False                  10  72f3df78  ...  127.0.0.1
# 11                None   True                   5  d39776e4  ...  127.0.0.1
# 12                None   True                  20  fb9d1ea3  ...  127.0.0.1
# 13                None   True                   5  a4fbdeef  ...  127.0.0.1
# 14                None   True                   5  63b1de1a  ...  127.0.0.1
# 15                None   True                   5  3a5a5f5a  ...  127.0.0.1
# 16                None  False                   5  79c18853  ...  127.0.0.1
# 17                None   True                   5  037850dd  ...  127.0.0.1
# 18                None   True                  10  092a6f87  ...  127.0.0.1
# 19                None   True                   5  4153dbda  ...  127.0.0.1
# 20                None   True                  10  d539805d  ...  127.0.0.1
# 21                None  False                  45  df1f5816  ...  127.0.0.1
# 22                None   True                  20  7a5d5426  ...  127.0.0.1
# 23                None   True                  10  420c0f21  ...  127.0.0.1
# 24                None  False                  30  b5e20efb  ...  127.0.0.1
#
#     time_since_restore  iterations_since_restore  config/n1 config/n2  \
# 0           437.791082                        10        200      1000
# 1           885.472061                        20        500       700
# 2           251.885737                         5        200       800
# 3          1123.941971                        25        400       700
# 4           457.793555                        10        600      1000
# 5           262.344955                         5        400       400
# 6           228.659175                         5        800       500
# 7          2316.187972                        50        300       600
# 8           236.921906                         5        700       500
# 9           473.260340                        10        500       800
# 10          466.116956                        10        800       200
# 11          242.179892                         5        800       700
# 12         1085.173282                        20        400       600
# 13          233.263319                         5       1000       300
# 14          238.796730                         5        500       900
# 15          238.361360                         5        600       800
# 16          267.981159                         5        300       800
# 17          229.706958                         5        400       300
# 18          465.884774                        10        500       300
# 19          234.330438                         5        800       700
# 20          548.524639                        10        100       600
# 21         2423.028576                        45        300       600
# 22          956.821233                        20        200       400
# 23          542.771926                        10        100       900
# 24         1665.945210                        30        300       500
#
#    config/n3  config/n4  config/n_epochs  config/lr    logdir
# 0        800        400               10   0.000539  0d2460cd
# 1        800        200               20   0.000338  c0a74e4c
# 2        200        100                5   0.000972  e53f86e8
# 3        500        800               25   0.000251  70073b7b
# 4        700        200               10   0.000138  9ba7349b
# 5        200        300               20   0.002260  08cbe69c
# 6        200        700               20   0.002278  5b460929
# 7        900        600               50   0.000138  a9b14748
# 8        800        900               35   0.007280  adf77d90
# 9        600        600               20   0.000402  1db87ec3
# 10       500        800               10   0.000305  72f3df78
# 11       900       1000               40   0.007135  d39776e4
# 12       300        200               35   0.000270  fb9d1ea3
# 13       700        100               15   0.001935  a4fbdeef
# 14       900        400               40   0.001102  63b1de1a
# 15       900        400               35   0.000611  3a5a5f5a
# 16       100        100                5   0.000478  79c18853
# 17       600        700               25   0.004845  037850dd
# 18       600        700               25   0.000107  092a6f87
# 19       100        900               25   0.001703  4153dbda
# 20       400        600               45   0.000179  d539805d
# 21       400        500               45   0.000172  df1f5816
# 22      1000        800               50   0.000100  7a5d5426
# 23       400        500               45   0.000202  420c0f21
# 24       400        500               30   0.000225  b5e20efb
#
# [25 rows x 25 columns]

# %% [markdown]
# Save the Result instance

# %%
with open('omega_result.pickle', 'wb') as out:
    pickle.dump(result, out)

# %% [markdown]
# Get best config, print it and save it

# %%
best_config = result.get_best_config(metric = 'valid_rmse', mode = 'min')
print(best_config)
with open('best_config_omega.pickle', 'wb') as out:
    pickle.dump(best_config, out)
# Out:
# {'n1': 400, 'n2': 700, 'n3': 500, 'n4': 800, 'n_epochs': 25, 'lr': 0.00025064735035985327}

# %% [markdown]
# Let's train the model. For the best config, RMSE for the test set (which we got earlier) is 0.103, $R^{2}$  is 0.67. Not much...

# %%
model = train_model(config = best_config, variable = 'omega', is_tune = False)
# Out:
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 0.01258296471357566  valid rmse is:  0.1586377301500224  R2 valid is  0.22426050901412964
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 0.012824881454523675  valid rmse is:  0.1601554335920182  R2 valid is  0.20934629440307617
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 0.008512900922422835  valid rmse is:  0.13048295614694538  R2 valid is  0.47517991065979004
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 0.008405127282535764  valid rmse is:  0.1296543657771366  R2 valid is  0.4818241000175476
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 0.007640213789380038  valid rmse is:  0.12361402662626954  R2 valid is  0.5289809703826904
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 0.009224867354525367  valid rmse is:  0.13582980051907143  R2 valid is  0.43128710985183716
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 0.008079238539174525  valid rmse is:  0.12711599851454203  R2 valid is  0.5019150972366333
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 0.005625905890651407  valid rmse is:  0.10607455765310933  R2 valid is  0.6531630158424377
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 0.004846493210540602  valid rmse is:  0.09845296552710438  R2 valid is  0.7012138366699219
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 0.007592261708362834  valid rmse is:  0.12322549824093092  R2 valid is  0.5319372415542603
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 0.004486129163901418  valid rmse is:  0.09472200550982246  R2 valid is  0.7234302759170532
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 0.0037035734383504115  valid rmse is:  0.08606478302244666  R2 valid is  0.7716747522354126
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 0.00468199234164305  valid rmse is:  0.09676768408557736  R2 valid is  0.7113553285598755
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 0.0037712672131390247  valid rmse is:  0.08684776581051495  R2 valid is  0.7675014734268188
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 0.0037934601016359456  valid rmse is:  0.08710292878699252  R2 valid is  0.7661333084106445
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 0.00405574544065604  valid rmse is:  0.09006381560489252  R2 valid is  0.7499634027481079
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 0.003452364597887196  valid rmse is:  0.08309470016658338  R2 valid is  0.7871618270874023
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 0.003302311338879141  valid rmse is:  0.0812688296812393  R2 valid is  0.7964125871658325
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 0.0033154344510891187  valid rmse is:  0.08143014737907722  R2 valid is  0.7956035137176514
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 0.0037361761748642736  valid rmse is:  0.08644276921598791  R2 valid is  0.7696648240089417
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 0.00327623581755396  valid rmse is:  0.08094733865364519  R2 valid is  0.7980201244354248
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 0.003134952123732583  valid rmse is:  0.07918272695143283  R2 valid is  0.8067302703857422
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 0.003607601777404526  valid rmse is:  0.08494235430460502  R2 valid is  0.7775914669036865
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 0.003400692790322184  valid rmse is:  0.08247051340112033  R2 valid is  0.7903473973274231
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 0.0052950389657155945  valid rmse is:  0.10290810430394288  R2 valid is  0.6735609769821167

# %% [markdown]
# Let's save a model to use it in calculator

# %%
torch.save(model, 'omega_model.pth')
