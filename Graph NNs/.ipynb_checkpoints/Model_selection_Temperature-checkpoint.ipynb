# %%
from rdkit import Chem
import chemlib
from chemlib import Element

import numpy as np
import pandas as pd
import os
from functools import partial

from ray import train
from ray import tune
from ray.tune.schedulers import ASHAScheduler

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import torch
import torch.nn as nn
from torch_geometric.data import Data, Dataset
from torch_geometric.nn import global_mean_pool, GraphConv, NNConv, EdgeConv
from torch_geometric.loader import DataLoader
device = 'cuda:0'
from ray.tune.search.hyperopt import HyperOptSearch
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# %%
path = os.path.abspath('') + '\\grouped_table.csv'

# %%
def load_data(abs_path = path, variable = 'Tc'):
    df = pd.read_csv(abs_path, index_col = 0)
    df = df[~df[variable].isnull()]
    df['mol'] = df['SMILES'].apply(lambda x: Chem.MolFromSmiles(x))
    quant = df[variable].quantile(q= 0.95)
    mask = df[variable] < quant
    df = df[mask]

    train_df, test_df = train_test_split(df, test_size = 0.2, random_state = 0)
    
    valid_df, test_df = train_test_split(test_df, test_size = 0.5, random_state = 0)
    return train_df, test_df, valid_df

# %%
train_df, test_df, valid_df = load_data()

# %%
def make_edge_features(mol):
    edge_features = np.zeros([mol.GetNumBonds(), 4])
    for i, bond in enumerate(mol.GetBonds()):
        if bond.GetBondTypeAsDouble() == 1.0:
            edge_features[i,0] = 1
        elif bond.GetBondTypeAsDouble() == 2.0:
            edge_features[i,1] = 1
        elif bond.GetBondTypeAsDouble() == 3.0:
            edge_features[i, 2] = 1
        else:
            edge_features[i, 3] = 1
    return torch.tensor(edge_features, dtype = torch.float32)

# %%
def make_x(mol):
    atom_properties = []
    
    for atom in mol.GetAtoms():
        _el = Element(atom.GetSymbol())
        atom_properties.append([atom.GetAtomicNum(), atom.GetMass(), int(atom.GetIsAromatic()), atom.GetExplicitValence(), 
                                atom.GetImplicitValence(), atom.GetTotalValence(), 
                                atom.GetNumExplicitHs(), atom.GetNumImplicitHs(), atom.GetTotalNumHs(),
                                atom.GetDegree(), atom.GetTotalDegree(), atom.GetFormalCharge(),
                               int(atom.IsInRing()), _el.Electronegativity, _el.FirstIonization, _el.AtomicRadius, _el.SpecificHeat
                               ])
    x = torch.tensor(atom_properties, dtype = torch.float32)
    return x

# %%
def make_edge_indices(mol):
    start_atoms = []
    end_atoms = []
    for bond in mol.GetBonds():
        start_atoms.append(bond.GetBeginAtomIdx())
        end_atoms.append(bond.GetEndAtomIdx())
    edge_indice = torch.tensor([start_atoms, end_atoms], dtype = torch.int64)
    return edge_indice

# %%
class CriticalDataset(Dataset):
    def __init__(self, frame, labels = None, transform = None, property = 'Tc'):
        super().__init__()
        self.property = property    
        self.df = frame[~frame[self.property].isnull()]
        self.labels = None
        self.transform = None
    def get(self, idx):
        mol = self.df['mol'].iloc[idx]
        #print(Chem.MolToSmiles(mol))
        try:
            x = make_x(mol)
        except:
            print('Invalid mol - cannot make x')
        try:
            edge_indices = make_edge_indices(mol)
        except:
            print('Invalid mol - cannot make edge indice')
        try:
            edge_features = make_edge_features(mol)
        except:
            print('Invalid mol - cannot make edge features')
        y = torch.tensor(self.df[self.property].iloc[idx], dtype = torch.float32)
        data = Data(x=x, edge_index=edge_indices, y = y, edge_features = edge_features)
        return data
    def len(self):
        return(len(self.df))

# %%
class GraphNet(nn.Module):
    def __init__(self, num_node_features = 17,
                n1 = 200,
                n2 = 500,
                n3 = 500,
                n4 = 500):
        super().__init__()
        conv_1_nn = nn.Sequential(nn.Linear(4, 200), nn.ReLU(), nn.Linear(200, 17*n1))
        self.conv_1 = NNConv(17, n1, nn = conv_1_nn)
        self.a1_con = nn.ReLU()
        
        conv_2_nn = nn.Sequential(nn.Linear(2*n1, n2), nn.ReLU(), nn.Linear(n2, n2))
        self.conv_2 = EdgeConv(nn = conv_2_nn)
        self.a2_con = nn.ReLU()
        
        conv_3_nn = nn.Sequential(nn.Linear(2*n2, n3), nn.ReLU(), nn.Linear(n3, n3))
        self.conv_3 = EdgeConv(nn = conv_3_nn)
        self.a3_con = nn.ReLU()
        
        self.conv_4 = GraphConv(in_channels = n3, out_channels = n4)
        self.a4_con = nn.ReLU()
        self.dropout_1 = nn.Dropout(p = 0.3)
        self.a1 = nn.CELU()
        self.linear_1 = nn.Linear(in_features = n4, out_features = 1000)
        self.a2 = nn.CELU()
        self.linear_2 = nn.Linear(in_features = 1000, out_features = 1000)
        self.a3 = nn.CELU()
        self.linear_3 = nn.Linear(in_features = 1000, out_features = 1)
    def forward(self, data):
        x, edge_index, edge_attrs =  (data.x, data.edge_index, data.edge_features)
        x = self.a1_con(self.conv_1(x = x, edge_index = edge_index, edge_attr = edge_attrs))
        x = self.a2_con(self.conv_2(x = x, edge_index = edge_index))
        x = self.a3_con(self.conv_3(x = x, edge_index = edge_index))
        x = self.a4_con(self.conv_4(x = x, edge_index = edge_index))
        if hasattr(data, 'batch'):
            x = global_mean_pool(x, batch = data.batch)
        else:
            x = torch.mean(x, dim = 0, keepdim = True)
        #x = self.a1(x)
        x = self.dropout_1(x)
        x = self.linear_1(x)
        x = self.a2(x)
        x = self.linear_2(x)
        x = self.a3(x)
        x = self.linear_3(x)
        return x

# %%
config = {
    "n1": tune.qrandint(100, 1000, 100),
    "n2": tune.qrandint(100, 1000, 100),
    "n3": tune.qrandint(100, 1000, 100),
    "n4": tune.qrandint(100, 1000, 100),
    "n_epochs": tune.qrandint(1, 50, 5),
    "lr": tune.loguniform(1e-4, 1e-2)}

# %%
def train_model(config = config, 
                abs_path  = path,
                variable = 'Tc',
                is_tune = True):

    train_df, test_df, valid_df = load_data(abs_path = abs_path, variable = variable)
    if is_tune:
        train_ds, test_ds,  valid_ds = (CriticalDataset(train_df), CriticalDataset(test_df), CriticalDataset(valid_df))
        train_dl, test_dl, valid_dl = (DataLoader(train_ds, batch_size=2), DataLoader(test_ds, batch_size =2),  DataLoader(valid_ds, batch_size=2))
    else:
        train_df = pd.concat([train_df, test_df])
        train_ds, valid_ds = (CriticalDataset(train_df), CriticalDataset(valid_df))
        train_dl, valid_dl = (DataLoader(train_ds, batch_size = 2), DataLoader(valid_ds, batch_size = 2))
        
    model = GraphNet(n1 = config['n1'], n2 = config['n2'], n3 = config['n3'], n4 = config['n4'])
    model.to(device)
    optimizer = torch.optim.Adam(params = model.parameters(), lr = config['lr'])
    loss_fn = nn.MSELoss()
    for epoch in range(config['n_epochs']):
        epoch_train_loss, epoch_valid_loss, epoch_train_rmse, epoch_valid_rmse, epoch_r2_valid, total_graphs = 0, 0, 0, 0, 0, 0
        model.train()
        for batch in train_dl:
            batch.to(device)
            output = model(batch)
            loss = loss_fn(output.flatten(), batch.y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            epoch_train_loss += loss.item()
            epoch_train_rmse += np.sqrt(loss.item())
            total_graphs += batch.num_graphs
        epoch_train_loss = epoch_train_loss / total_graphs
        epoch_train_rmse = epoch_train_rmse / total_graphs
        model.eval()
        total_graphs = 0
        predictions = []
        ys = []
        for batch in valid_dl:
            batch.to(device)
            output = model(batch)
            loss = loss_fn(output.flatten(), batch.y)
            epoch_valid_loss += loss.item()
            epoch_valid_rmse += np.sqrt(loss.item())
            total_graphs += batch.num_graphs
            predictions.append(output)
            ys.append(batch.y)
        predictions = torch.cat(predictions, dim = 0).detach().cpu().numpy()
        ys = torch.cat(ys, dim = 0).detach().cpu().numpy()
        epoch_valid_loss = epoch_valid_loss / total_graphs
        epoch_valid_rmse = epoch_valid_rmse / total_graphs
        epoch_r2_valid = r2_score(ys, predictions.squeeze())
        if not is_tune:
            print('vali loss is:', epoch_valid_loss, ' valid rmse is: ', epoch_valid_rmse, ' R2 valid is ',  epoch_r2_valid)
        if is_tune:
            train.report({'train_loss':epoch_train_loss,
                          'train_rmse':epoch_train_rmse,
                          'valid_loss':epoch_valid_loss,
                          'valid_rmse':epoch_valid_rmse,
                          'r2_valid':epoch_r2_valid})
    if not is_tune:
        sns.scatterplot(x = predictions.squeeze(), y = ys)
        return model

# %%
config = {
    "n1": 200,
    "n2": 500,
    "n3": 500,
    "n4": 500,
    "n_epochs": 3,
    "lr": 0.0001}
model = train_model(config = config, is_tune = False)
# Out:
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# 2686.0981726011673   31.56853306256297   0.40513765811920166
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# 1650.3949368944416   23.963402638501403   0.6345040798187256
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# 1488.8707464221236   22.338538228962953   0.6702752113342285

# %%
hpt_search = HyperOptSearch(metric = 'valid_loss', mode = 'min')

# %%
max_num_epochs = 50
scheduler = ASHAScheduler(metric = 'valid_loss', mode = 'min', max_t = max_num_epochs, grace_period= 5, reduction_factor=2)

# %%
result = tune.run(partial(train_model), search_alg = hpt_search, config = config, num_samples = 20, scheduler = scheduler, resources_per_trial={'gpu':1})
# Out:
# 2025-02-18 17:55:04,861	INFO tune.py:616 -- [output] This uses the legacy output and progress reporter, as Jupyter notebooks are not supported by the new engine, yet. For more information, please see https://github.com/ray-project/ray/issues/36949
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2025-02-18 20:00:14</td></tr>
# <tr><td>Running for: </td><td>02:05:09.18        </td></tr>
# <tr><td>Memory:      </td><td>14.7/31.9 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using AsyncHyperBand: num_stopped=12<br>Bracket: Iter 40.000: -490.22464638140485 | Iter 20.000: -640.6575858230134 | Iter 10.000: -825.7801126427464 | Iter 5.000: -1585.2365575216033<br>Logical resource usage: 0/16 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name          </th><th>status    </th><th>loc            </th><th style="text-align: right;">         lr</th><th style="text-align: right;">  n1</th><th style="text-align: right;">  n2</th><th style="text-align: right;">  n3</th><th style="text-align: right;">  n4</th><th style="text-align: right;">  n_epochs</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  train_loss</th><th style="text-align: right;">  train_rmse</th><th style="text-align: right;">  valid_loss</th></tr>
# </thead>
# <tbody>
# <tr><td>train_model
# <tr><td>train_model_da9cb791</td><td style="text-align: right;"> 0.684384 </td><td style="text-align: right;">    2034.37 </td><td style="text-align: right;">     26.5242</td><td style="text-align: right;">    1425.16 </td><td style="text-align: right;">     22.4014</td></tr>
# <tr><td>train_model_e268d81c</td><td style="text-align: right;">-0.0594819</td><td style="text-align: right;">    5141.65 </td><td style="text-align: right;">     44.3641</td><td style="text-align: right;">    4784.09 </td><td style="text-align: right;">     42.192 </td></tr>
# <tr><td>train_model_eee5d616</td><td style="text-align: right;"> 0.891435 </td><td style="text-align: right;">     444.424</td><td style="text-align: right;">     12.033 </td><td style="text-align: right;">     490.225</td><td style="text-align: right;">     12.1381</td></tr>
# <tr><td>train_model_f04f7c5d</td><td style="text-align: right;"> 0.885698 </td><td style="text-align: right;">     658.056</td><td style="text-align: right;">     14.6784</td><td style="text-align: right;">     516.128</td><td style="text-align: right;">     12.902 </td></tr>
# </tbody>
# </table>
# </div>
# <style>
# .trialProgress {
#   display: flex;
#   flex-direction: column;
#   color: var(--jp-ui-font-color1);
# }
# .trialProgress h3 {
#   font-weight: bold;
# }
# .trialProgress td {
#   white-space: nowrap;
# }
# </style>
# (func pid=21244) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=21244)   warnings.warn(message)
# (func pid=21244) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=21244)   warnings.warn(message)
# (func pid=21244) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=21244)   warnings.warn(message)
# (func pid=21244) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=21244)   warnings.warn(message)
# (func pid=21244) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=21244)   warnings.warn(message)
# (func pid=21244) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=21244)   warnings.warn(message)
# (func pid=21244) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=21244)   warnings.warn(message)
# (func pid=21244) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=21244)   warnings.warn(message)
# (func pid=21244) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=21244)   warnings.warn(message)
# (func pid=21244) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=21244)   warnings.warn(message)
# (func pid=21244) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=21244)   warnings.warn(message)
# (func pid=21244) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=21244)   warnings.warn(message)
# (func pid=21244) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=21244)   warnings.warn(message)
# (func pid=21244) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=21244)   warnings.warn(message)
# (func pid=21244) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=21244)   warnings.warn(message)
# (func pid=21244) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=21244)   warnings.warn(message)
# (func pid=21244) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=21244)   warnings.warn(message)
# (func pid=21244) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=21244)   warnings.warn(message)
# (func pid=21244) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=21244)   warnings.warn(message)
# (func pid=21244) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=21244)   warnings.warn(message)
# (func pid=21244) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=21244)   warnings.warn(message)
# (func pid=21244) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=21244)   warnings.warn(message)
# (func pid=21244) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=21244)   warnings.warn(message)
# (func pid=21244) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=21244)   warnings.warn(message)
# (func pid=21244) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=21244)   warnings.warn(message)
# (func pid=21244) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=21244)   warnings.warn(message)
# (func pid=21244) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=21244)   warnings.warn(message)
# (func pid=21244) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=21244)   warnings.warn(message)
# (func pid=21244) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=21244)   warnings.warn(message)
# (func pid=21244) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=21244)   warnings.warn(message)
# (func pid=21244) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=21244)   warnings.warn(message)
# (func pid=21244) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=21244)   warnings.warn(message)
# (func pid=21244) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=21244)   warnings.warn(message)
# (func pid=21244) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=21244)   warnings.warn(message)
# (func pid=21244) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=21244)   warnings.warn(message)
# (func pid=21244) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=21244)   warnings.warn(message)
# (func pid=21244) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=21244)   warnings.warn(message)
# (func pid=21244) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=21244)   warnings.warn(message)
# (func pid=21244) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=21244)   warnings.warn(message)
# (func pid=21244) D:\bld\apache-arrow_1692865689659\work\cpp\src\arrow\filesystem\s3fs.cc:2829:  arrow::fs::FinalizeS3 was not called even though S3 was initialized.  This could lead to a segmentation fault at exit
# (pid=22928) Windows fatal exception: code 0xc0000139
# (pid=22928)
# (pid=22928) Stack (most recent call first):
# (pid=22928)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\ctypes\__init__.py", line 376 in __init__
# (pid=22928)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\_ops.py", line 1350 in load_library
# (pid=22928)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_scatter\__init__.py", line 16 in <module>
# (pid=22928)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=22928)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=22928)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=22928)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=22928)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=22928)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\typing.py", line 82 in <module>
# (pid=22928)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=22928)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=22928)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=22928)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=22928)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=22928)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\__init__.py", line 4 in <module>
# (pid=22928)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=22928)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=22928)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=22928)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=22928)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=22928)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=22928)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (pid=22928)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=22928)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=22928)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (pid=22928)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=22928)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\function_manager.py", line 647 in _load_actor_class_from_gcs
# (pid=22928)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\function_manager.py", line 544 in load_actor_class
# (pid=22928)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\worker.py", line 920 in main_loop
# (pid=22928)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\workers\default_worker.py", line 289 in <module>
# (pid=22928) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\typing.py:86: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: [WinError 127] Не найдена указанная процедура
# (pid=22928)   warnings.warn(f"An issue occurred while importing 'torch-scatter'. "
# (pid=22928) Windows fatal exception: code 0xc0000139
# (pid=22928)
# (pid=22928) Stack (most recent call first):
# (pid=22928)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\ctypes\__init__.py", line 376 in __init__
# (pid=22928)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\_ops.py", line 1350 in load_library
# (pid=22928)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_scatter\__init__.py", line 16 in <module>
# (pid=22928)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=22928)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=22928)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=22928)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=22928)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=22928)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_sparse\storage.py", line 5 in <module>
# (pid=22928)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=22928)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=22928)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=22928)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=22928)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=22928)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_sparse\__init__.py", line 39 in <module>
# (pid=22928)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=22928)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=22928)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=22928)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=22928)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=22928)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\typing.py", line 119 in <module>
# (pid=22928)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=22928)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=22928)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=22928)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=22928)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=22928)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\__init__.py", line 4 in <module>
# (pid=22928)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=22928)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=22928)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=22928)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=22928)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=22928)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=22928)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (pid=22928)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=22928)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=22928)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (pid=22928)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=22928)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\function_manager.py", line 647 in _load_actor_class_from_gcs
# (pid=22928)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\function_manager.py", line 544 in load_actor_class
# (pid=22928)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\worker.py", line 920 in main_loop
# (pid=22928)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\workers\default_worker.py", line 289 in <module>
# (pid=22928) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: [WinError 127] Не найдена указанная процедура
# (pid=22928)   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "
# (func pid=22928) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=22928)   warnings.warn(message)
# (func pid=22928) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=22928)   warnings.warn(message)
# (func pid=22928) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=22928)   warnings.warn(message)
# (func pid=22928) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=22928)   warnings.warn(message)
# (func pid=22928) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=22928)   warnings.warn(message)
# (pid=15272) Windows fatal exception: code 0xc0000139
# (pid=15272)
# (pid=15272) Stack (most recent call first):
# (pid=15272)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\ctypes\__init__.py", line 376 in __init__
# (pid=15272)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\_ops.py", line 1350 in load_library
# (pid=15272)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_scatter\__init__.py", line 16 in <module>
# (pid=15272)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=15272)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=15272)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=15272)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=15272)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=15272)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\typing.py", line 82 in <module>
# (pid=15272)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=15272)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=15272)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=15272)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=15272)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=15272)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\__init__.py", line 4 in <module>
# (pid=15272)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=15272)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=15272)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=15272)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=15272)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=15272)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=15272)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (pid=15272)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=15272)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=15272)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (pid=15272)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=15272)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\function_manager.py", line 647 in _load_actor_class_from_gcs
# (pid=15272)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\function_manager.py", line 544 in load_actor_class
# (pid=15272)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\worker.py", line 920 in main_loop
# (pid=15272)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\workers\default_worker.py", line 289 in <module>
# (pid=15272) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\typing.py:86: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: [WinError 127] Не найдена указанная процедура
# (pid=15272)   warnings.warn(f"An issue occurred while importing 'torch-scatter'. "
# (pid=15272) Windows fatal exception: code 0xc0000139
# (pid=15272)
# (pid=15272) Stack (most recent call first):
# (pid=15272)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\ctypes\__init__.py", line 376 in __init__
# (pid=15272)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\_ops.py", line 1350 in load_library
# (pid=15272)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_scatter\__init__.py", line 16 in <module>
# (pid=15272)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=15272)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=15272)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=15272)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=15272)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=15272)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_sparse\storage.py", line 5 in <module>
# (pid=15272)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=15272)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=15272)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# ...
# (pid=19644)   warnings.warn(f"An issue occurred while importing 'torch-scatter'. "
# (pid=19644) Windows fatal exception: code 0xc0000139
# (pid=19644)
# (pid=19644) Stack (most recent call first):
# (pid=19644)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\ctypes\__init__.py", line 376 in __init__
# (pid=19644)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\_ops.py", line 1350 in load_library
# (pid=19644)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_scatter\__init__.py", line 16 in <module>
# (pid=19644)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=19644)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=19644)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=19644)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=19644)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=19644)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_sparse\storage.py", line 5 in <module>
# (pid=19644)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=19644)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=19644)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=19644)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=19644)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=19644)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_sparse\__init__.py", line 39 in <module>
# (pid=19644)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=19644)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=19644)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=19644)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=19644)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=19644)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\typing.py", line 119 in <module>
# (pid=19644)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=19644)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=19644)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=19644)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=19644)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=19644)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\__init__.py", line 4 in <module>
# (pid=19644)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=19644)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=19644)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=19644)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=19644)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=19644)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=19644)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (pid=19644)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=19644)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=19644)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (pid=19644)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=19644)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\function_manager.py", line 647 in _load_actor_class_from_gcs
# (pid=19644)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\function_manager.py", line 544 in load_actor_class
# (pid=19644)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\worker.py", line 920 in main_loop
# (pid=19644)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\workers\default_worker.py", line 289 in <module>
# (pid=19644) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: [WinError 127] Не найдена указанная процедура
# (pid=19644)   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "
# (func pid=19644) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=19644)   warnings.warn(message)
# (func pid=19644) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=19644)   warnings.warn(message)
# (func pid=19644) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=19644)   warnings.warn(message)
# (func pid=19644) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=19644)   warnings.warn(message)
# (func pid=19644) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=19644)   warnings.warn(message)
# (pid=15952) Windows fatal exception: code 0xc0000139
# (pid=15952)
# (pid=15952) Stack (most recent call first):
# (pid=15952)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\ctypes\__init__.py", line 376 in __init__
# (pid=15952)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\_ops.py", line 1350 in load_library
# (pid=15952)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_scatter\__init__.py", line 16 in <module>
# (pid=15952)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=15952)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=15952)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=15952)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=15952)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=15952)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\typing.py", line 82 in <module>
# (pid=15952)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=15952)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=15952)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=15952)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=15952)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=15952)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\__init__.py", line 4 in <module>
# (pid=15952)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=15952)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=15952)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=15952)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=15952)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=15952)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=15952)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (pid=15952)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=15952)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=15952)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (pid=15952)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=15952)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\function_manager.py", line 647 in _load_actor_class_from_gcs
# (pid=15952)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\function_manager.py", line 544 in load_actor_class
# (pid=15952)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\worker.py", line 920 in main_loop
# (pid=15952)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\workers\default_worker.py", line 289 in <module>
# (pid=15952) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\typing.py:86: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: [WinError 127] Не найдена указанная процедура
# (pid=15952)   warnings.warn(f"An issue occurred while importing 'torch-scatter'. "
# (pid=15952) Windows fatal exception: code 0xc0000139
# (pid=15952)
# (pid=15952) Stack (most recent call first):
# (pid=15952)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\ctypes\__init__.py", line 376 in __init__
# (pid=15952)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch\_ops.py", line 1350 in load_library
# (pid=15952)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_scatter\__init__.py", line 16 in <module>
# (pid=15952)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=15952)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=15952)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=15952)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=15952)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=15952)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_sparse\storage.py", line 5 in <module>
# (pid=15952)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=15952)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=15952)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=15952)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=15952)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=15952)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_sparse\__init__.py", line 39 in <module>
# (pid=15952)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=15952)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=15952)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=15952)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=15952)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=15952)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\typing.py", line 119 in <module>
# (pid=15952)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=15952)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=15952)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=15952)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=15952)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=15952)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\__init__.py", line 4 in <module>
# (pid=15952)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=15952)   File "<frozen importlib._bootstrap_external>", line 940 in exec_module
# (pid=15952)   File "<frozen importlib._bootstrap>", line 690 in _load_unlocked
# (pid=15952)   File "<frozen importlib._bootstrap>", line 1147 in _find_and_load_unlocked
# (pid=15952)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=15952)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=15952)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (pid=15952)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=15952)   File "<frozen importlib._bootstrap>", line 241 in _call_with_frames_removed
# (pid=15952)   File "<frozen importlib._bootstrap>", line 1126 in _find_and_load_unlocked
# (pid=15952)   File "<frozen importlib._bootstrap>", line 1176 in _find_and_load
# (pid=15952)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\function_manager.py", line 647 in _load_actor_class_from_gcs
# (pid=15952)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\function_manager.py", line 544 in load_actor_class
# (pid=15952)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\worker.py", line 920 in main_loop
# (pid=15952)   File "C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\ray\_private\workers\default_worker.py", line 289 in <module>
# (pid=15952) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: [WinError 127] Не найдена указанная процедура
# (pid=15952)   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "
# (func pid=15952) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=15952)   warnings.warn(message)
# (func pid=15952) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=15952)   warnings.warn(message)
# (func pid=15952) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=15952)   warnings.warn(message)
# (func pid=15952) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=15952)   warnings.warn(message)
# (func pid=15952) C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
# (func pid=15952)   warnings.warn(message)
# 2025-02-18 20:00:14,076	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to 'C:/Users/Timur/ray_results/train_model_2025-02-18_17-55-04' in 0.0245s.
# 2025-02-18 20:00:14,082	INFO tune.py:1041 -- Total run time: 7509.22 seconds (7509.15 seconds for the tuning loop).

# %%
result.dataframe()
# Out:
#       train_loss  train_rmse   valid_loss  valid_rmse  r2_valid   timestamp  \
# 0     444.424419   12.033044   490.224646   12.138054  0.891435  1739891760
# 1    2244.437217   28.280661  1898.281105   25.803413  0.579607  1739891918
# 2    3025.739823   32.324088  2899.112730   31.122794  0.357964  1739892069
# 3   15535.568236   28.146529  1417.542850   22.030493  0.686071  1739892382
# 4     765.115701   16.081089   678.889551   15.066656  0.849653  1739892972
# 5    2034.366226   26.524227  1425.162619   22.401397  0.684384  1739893130
# 6     634.182049   14.453823   700.562687   15.489027  0.844854  1739893738
# 7     460.354292   12.144053   610.039347   13.404952  0.864901  1739894688
# 8    1553.129960   23.200310  1134.866877   19.527206  0.748673  1739894844
# 9    1038.124646   18.886411  1037.223754   18.993864  0.770297  1739895141
# 10   2246.702356   28.468459  2181.517919   27.901652  0.516882  1739895295
# 11   5044.328805   43.901434  4827.647027   42.415055 -0.069129  1739895450
# 12    658.055581   14.678384   516.128220   12.901988  0.885698  1739896030
# 13    919.376761   17.470586   772.259860   15.885009  0.828976  1739896335
# 14   5616.544739   46.470157  5906.849429   47.923179 -0.308129  1739896496
# 15   5141.649915   44.364098  4784.085722   42.191963 -0.059482  1739896647
# 16   2394.922525   29.248750  4584.526394   35.538197 -0.015288  1739896807
# 17    401.255072   11.366699   575.186428   12.832936  0.872619  1739897701
# 18   4141.759860   32.247835  4162.184014   35.464998  0.078244  1739897859
# 19   5005.828221   43.696237  4904.247498   42.807475 -0.086093  1739898014
#
#    checkpoint_dir_name   done  training_iteration  trial_id  ...    node_ip  \
# 0                 None  False                  40  eee5d616  ...  127.0.0.1
# 1                 None   True                   5  9b072879  ...  127.0.0.1
# 2                 None   True                   5  ce6132b2  ...  127.0.0.1
# 3                 None   True                  10  c285112b  ...  127.0.0.1
# 4                 None  False                  20  6c47c137  ...  127.0.0.1
# 5                 None  False                   5  da9cb791  ...  127.0.0.1
# 6                 None   True                  20  14685f41  ...  127.0.0.1
# 7                 None  False                  30  6118f768  ...  127.0.0.1
# 8                 None  False                   5  69614845  ...  127.0.0.1
# 9                 None   True                  10  62546d67  ...  127.0.0.1
# 10                None   True                   5  7cb885d8  ...  127.0.0.1
# 11                None   True                   5  c20b032d  ...  127.0.0.1
# 12                None  False                  20  f04f7c5d  ...  127.0.0.1
# 13                None  False                  10  13b35b84  ...  127.0.0.1
# 14                None   True                   5  39049db4  ...  127.0.0.1
# 15                None   True                   5  e268d81c  ...  127.0.0.1
# 16                None   True                   5  162513d4  ...  127.0.0.1
# 17                None  False                  30  22f5ba74  ...  127.0.0.1
# 18                None   True                   5  845cc6aa  ...  127.0.0.1
# 19                None   True                   5  d412e837  ...  127.0.0.1
#
#     time_since_restore  iterations_since_restore  config/n1 config/n2  \
# 0          1250.381652                        40        900      1000
# 1           151.550778                         5        400       500
# 2           144.484073                         5        400       200
# 3           306.747910                        10        900       800
# 4           584.353126                        20        500       200
# 5           152.256014                         5        500       900
# 6           602.240550                        20        700       700
# 7           944.642829                        30       1000      1000
# 8           149.866689                         5        800      1000
# 9           291.253304                        10        600       100
# 10          148.707907                         5        200      1000
# 11          149.533137                         5        700       400
# 12          573.084081                        20        300       700
# 13          298.268002                        10       1000       200
# 14          155.012122                         5        900       600
# 15          144.559935                         5        600       200
# 16          154.422558                         5        800       500
# 17          887.154021                        30        400       400
# 18          152.401405                         5        900       700
# 19          148.112099                         5        200       700
#
#    config/n3  config/n4  config/n_epochs  config/lr    logdir
# 0        800        700               40   0.000594  eee5d616
# 1        800        800               35   0.000992  9b072879
# 2        300        100               15   0.007004  ce6132b2
# 3        400        600               45   0.001124  c285112b
# 4        600        100               20   0.000788  6c47c137
# 5        700        100                5   0.000597  da9cb791
# 6        600        700               20   0.000643  14685f41
# 7        800        500               30   0.000178  6118f768
# 8        200        200                5   0.000241  69614845
# 9        800        100               15   0.000293  62546d67
# 10       500        900               45   0.000819  7cb885d8
# 11       800        700               30   0.004384  c20b032d
# 12       100        200               20   0.000738  f04f7c5d
# 13       500        400               10   0.000213  13b35b84
# 14       900        900               45   0.004631  39049db4
# 15       300        600               25   0.008263  e268d81c
# 16       900        900               25   0.001094  162513d4
# 17       600        900               30   0.000137  22f5ba74
# 18       400        800               45   0.001766  845cc6aa
# 19       700        600               15   0.006825  d412e837
#
# [20 rows x 25 columns]

# %%
with open('temperature_result.pickle', 'wb') as out:
    pickle.dump(result, out)

# %%
best_config = result.get_best_config(metric = 'valid_rmse', mode = 'min')

# %%
model = train_model(config = best_config, variable = 'Tc', is_tune = False)
# Out:
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 2843.5152730601176  valid rmse is:  31.63705608260246  R2 valid is  0.3702760934829712
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 3991.9810116666476  valid rmse is:  39.918128059461424  R2 valid is  0.11593717336654663
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 2330.9308657057873  valid rmse is:  29.3121934096873  R2 valid is  0.48379284143447876
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 1559.7738778848359  valid rmse is:  22.862249139498847  R2 valid is  0.6545729637145996
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 1500.9769207633935  valid rmse is:  22.944805605765858  R2 valid is  0.6675941944122314
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 1313.4502384383957  valid rmse is:  21.298404927215874  R2 valid is  0.7091237306594849
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 1062.7047215947857  valid rmse is:  18.968165372113276  R2 valid is  0.7646538019180298
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 951.8604612838138  valid rmse is:  18.237423618265687  R2 valid is  0.7892013192176819
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 1026.1349615874615  valid rmse is:  19.165174462585018  R2 valid is  0.7727525234222412
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 758.705404072613  valid rmse is:  15.898842155803809  R2 valid is  0.831977367401123
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 748.147191294215  valid rmse is:  15.30850609543883  R2 valid is  0.8343155384063721
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 699.8704983615256  valid rmse is:  14.986085519368544  R2 valid is  0.8450069427490234
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 694.942715031373  valid rmse is:  14.77013432558278  R2 valid is  0.8460982441902161
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 701.5369802934734  valid rmse is:  15.020625949235628  R2 valid is  0.8446378707885742
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 618.961860789107  valid rmse is:  13.662702485378366  R2 valid is  0.8629249334335327
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 559.4811055130966  valid rmse is:  12.952495716954546  R2 valid is  0.8760975003242493
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 669.8425595170105  valid rmse is:  14.85358160102044  R2 valid is  0.8516569137573242
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 502.92332349891785  valid rmse is:  12.47035551661568  R2 valid is  0.8886227607727051
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 513.6156733049588  valid rmse is:  12.550908685127322  R2 valid is  0.8862548470497131
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 522.6467706115989  valid rmse is:  12.852660443444849  R2 valid is  0.8842548131942749
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 542.0008892679176  valid rmse is:  13.444519072927134  R2 valid is  0.8799686431884766
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 455.69543179637424  valid rmse is:  11.934627829052186  R2 valid is  0.899081826210022
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 545.2609548983829  valid rmse is:  13.00242031154747  R2 valid is  0.879246711730957
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 501.4456788193096  valid rmse is:  12.559240946009494  R2 valid is  0.888949990272522
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 477.687418309125  valid rmse is:  12.050491258502051  R2 valid is  0.8942115306854248
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 408.66381296902506  valid rmse is:  11.069081445436346  R2 valid is  0.9094974398612976
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 500.63346467602565  valid rmse is:  12.379282197778176  R2 valid is  0.8891298770904541
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 488.1439463465245  valid rmse is:  12.008670490893008  R2 valid is  0.8918957710266113
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 480.7532447576523  valid rmse is:  12.042164738889557  R2 valid is  0.8935325741767883
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 459.2732125876786  valid rmse is:  11.772299602931072  R2 valid is  0.8982895016670227
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 472.0505266905605  valid rmse is:  11.572941636072882  R2 valid is  0.8954598307609558
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 432.8512889506755  valid rmse is:  10.991054166450187  R2 valid is  0.9041408896446228
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 469.549534762254  valid rmse is:  11.282170483291404  R2 valid is  0.8960137367248535
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 468.1427319541864  valid rmse is:  11.633395410389861  R2 valid is  0.8963252902030945
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 503.7351002716399  valid rmse is:  12.76394811551297  R2 valid is  0.8884429931640625
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 503.4522732825248  valid rmse is:  11.745918581097845  R2 valid is  0.8885056376457214
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 453.59565680885277  valid rmse is:  11.27534371375126  R2 valid is  0.8995468616485596
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 454.5010256860163  valid rmse is:  11.12577215652485  R2 valid is  0.8993463516235352
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 447.4209915087982  valid rmse is:  11.100563079004772  R2 valid is  0.9009143114089966
# C:\Users\Timur\anaconda3\envs\ChemInfo-Pytorch\Lib\site-packages\torch_geometric\warnings.py:11: UserWarning: The usage of `scatter(reduce='max')` can be accelerated via the 'torch-scatter' package, but it was not found
#   warnings.warn(message)
# vali loss is: 519.2716095966179  valid rmse is:  12.43061916173469  R2 valid is  0.8850022554397583

# %%
with open('best_config_temperature.pickle', 'wb') as out:
    pickle.dump(best_config, out)
torch.save(model, 'temperature_model.pth')
